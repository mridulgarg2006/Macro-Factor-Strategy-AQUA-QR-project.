# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
macro_df = pd.read_csv("https://raw.githubusercontent.com/MananJain-IITK/AQUA_Project_CSV/refs/heads/main/Macro_Indicators.csv")

# %%
macro_df
# Out:
#       Period GDP At Market Prices \n(At Current Prices)\n(₹ Crore)  \
# 0   Jun-2024                                       7,730,979.44
# 1   Mar-2024                                       7,828,147.61
# 2   Dec-2023                                       7,567,704.65
# 3   Sep-2023                                       7,090,220.61
# 4   Jun-2023                                       7,049,593.97
# 5   Mar-2023                                       7,123,164.79
# 6   Dec-2022                                       6,858,114.71
# 7   Sep-2022                                       6,468,804.34
# 8   Jun-2022                                       6,499,562.02
# 9   Mar-2022                                       6,523,590.76
# 10  Dec-2021                                       6,268,323.17
# 11  Sep-2021                                       5,627,314.53
# 12  Jun-2021                                       5,178,170.07
# 13  Mar-2021                                       5,757,700.77
# ...
